# %%
from datetime import datetime
import os
import pyopenstates
import sys

def get_state_abbr(state):
    return state.get('abbreviation')


def query_state(state, search_terms):
    """
    https://openstates.github.io/pyopenstates/pyopenstates%20module.html#pyopenstates.search_bills
    uses keyworded argument in function
    """
    print('Query for ' + state + ' bills')

    bills = pyopenstates.search_bills(state=state, q=search_terms)

    return bills

# %%
pyopenstates.set_api_key('api key here')

metadata = pyopenstates.get_metadata()
states = list(map(get_state_abbr, metadata))

# %%
search = 'firearms'

states_bills_firearms = {}

for state in states:
    bills = query_state(state, search)
    states_bills_firearms[state] = bills
# Out:
# Query for al bills
# Query for ak bills
# Query for az bills
# Query for ar bills
# Query for ca bills
# Query for co bills
# Query for ct bills
# Query for de bills
# Query for dc bills
# Query for fl bills
# Query for ga bills
# Query for hi bills
# Query for id bills
# Query for il bills
# Query for in bills
# Query for ia bills
# Query for ks bills
# Query for ky bills
# Query for la bills
# Query for me bills
# Query for md bills
# Query for ma bills
# Query for mi bills
# Query for mn bills
# Query for ms bills
# Query for mo bills
# Query for mt bills
# Query for ne bills
# Query for nv bills
# Query for nh bills
# Query for nj bills
# Query for nm bills
# Query for ny bills
# Query for nc bills
# Query for nd bills
# Query for oh bills
# Query for ok bills
# Query for or bills
# Query for pa bills
# Query for pr bills
# Query for ri bills
# Query for sc bills
# Query for sd bills
# Query for tn bills
# Query for tx bills
# Query for ut bills
# Query for vt bills
# Query for va bills
# Query for wa bills
# Query for wv bills
# Query for wi bills
# Query for wy bills

# %%
print(us_bills['tx'])
# Out:
# [{u'title': u'Relating to an exemption from the sales tax for firearms and hunting supplies for a limited period.', u'created_at': datetime.datetime(2017, 7, 24, 5, 20, 12), u'updated_at': datetime.datetime(2017, 8, 1, 5, 30, 49), u'chamber': u'lower', u'state': u'tx', u'session': u'851', u'subjects': [u'Commerce', u'Animal Rights and Wildlife Issues', u'Budget, Spending, and Taxes', u'Guns'], u'type': [u'bill'], u'id': u'TXB00058778', u'bill_id': u'HB 216'}, {u'title': u'Relating to restrictive covenants regarding firearms or firearms ammunition.', u'created_at': datetime.datetime(2017, 3, 11, 8, 35, 13), u'updated_at': datetime.datetime(2017, 6, 5, 10, 27, 59), u'chamber': u'upper', u'state': u'tx', u'session': u'85', u'subjects': [u'Housing and Property', u'Other', u'Guns'], u'type': [u'bill'], u'id': u'TXB00055618', u'bill_id': u'SB 1943'}, {u'title': u'Relating to the regulation or taxation of firearms, air guns, knives, or ammunition by a municipality or county.', u'created_at': datetime.datetime(2017, 1, 18, 3, 3, 26), u'updated_at': datetime.datetime(2017, 6, 16, 10, 11, 59), u'chamber': u'upper', u'state': u'tx', u'session': u'85', u'subjects': [u'Budget, Spending, and Taxes', u'Municipal and County Issues', u'Guns'], u'type': [u'bill'], u'id': u'TXB00049522', u'bill_id': u'SB 459'}, {u'title': u'Relating to the transportation and storage of firearms and ammunition in private vehicles on the campuses of institutions of higher education.', u'created_at': datetime.datetime(2017, 2, 27, 6, 46, 3), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 45), u'chamber': u'lower', u'state': u'tx', u'session': u'85', u'subjects': [u'Education', u'Guns'], u'type': [u'bill'], u'id': u'TXB00051879', u'bill_id': u'HB 2105'}, {u'title': u'Relating to the enforcement of certain federal laws regulating firearms, firearm accessories, and firearm ammunition within the State of Texas.', u'created_at': datetime.datetime(2016, 12, 28, 0, 23, 53), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 10), u'chamber': u'lower', u'state': u'tx', u'session': u'85', u'subjects': [u'Judiciary', u'Executive Branch', u'Crime', u'Campaign Finance and Election Issues', u'State Agencies', u'Guns'], u'type': [u'bill'], u'id': u'TXB00048160', u'bill_id': u'HB 110'}, {u'title': u'Relating to the enforcement of certain federal laws regulating firearms, firearm accessories, and firearm ammunition; creating a criminal offense.', u'created_at': datetime.datetime(2016, 12, 28, 0, 23, 54), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 40), u'chamber': u'lower', u'state': u'tx', u'session': u'85', u'subjects': [u'Guns'], u'type': [u'bill'], u'id': u'TXB00048403', u'bill_id': u'HB 99'}, {u'title': u'Relating to the regulation of firearms, air guns, knives, ammunition, and firearm and air gun supplies; imposing a civil penalty.', u'created_at': datetime.datetime(2017, 1, 18, 3, 3, 24), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 29), u'chamber': u'lower', u'state': u'tx', u'session': u'85', u'subjects': [u'Campaign Finance and Election Issues', u'Guns', u'Municipal and County Issues', u'Executive Branch'], u'type': [u'bill'], u'id': u'TXB00049463', u'bill_id': u'HB 927'}, {u'title': u'Relating to an exemption from the sales tax for firearms and hunting supplies for a limited period.', u'created_at': datetime.datetime(2016, 12, 28, 0, 23, 54), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 49), u'chamber': u'lower', u'state': u'tx', u'session': u'85', u'subjects': [u'Commerce', u'Animal Rights and Wildlife Issues', u'Budget, Spending, and Taxes', u'Guns'], u'type': [u'bill'], u'id': u'TXB00048379', u'bill_id': u'HB 485'}, {u'title': u'Relating to the enforcement of certain federal laws regulating firearms, firearm accessories, and firearm ammunition.', u'created_at': datetime.datetime(2017, 1, 10, 5, 54, 41), u'updated_at': datetime.datetime(2017, 6, 5, 10, 28, 9), u'chamber': u'upper', u'state': u'tx', u'session': u'85', u'subjects': [u'Gun ...
